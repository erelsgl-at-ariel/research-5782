# %%
import logging

#create and configure logger
logging.basicConfig(filename= 'my_logging.log')
logger = logging.getLogger()

# %%
import logging

#create and configure logger
logging.basicConfig(filename= 'my_logging.log' ,level= logging.DEBUG)
logger = logging.getLogger()

# Test the logger
logger.info('This is a message')

# %%
with open('my_logging.log') as file:
    print(file.read())
# Out:
# INFO:root:This is a message

# %%
import logging

LOGֹֹֹFORMAT = "%(levelname)s, time: %(asctime)s , line: %(lineno)d- %(message)s "
#create and configure logger
logging.basicConfig(filename= 'my_logging.log' ,level= logging.DEBUG, format= LOGֹֹֹFORMAT)
logger = logging.getLogger()

# Test the logger
logger.info('This is a message')

# %%
with open('my_logging.log') as file:
    print(file.read())
# Out:
# INFO:root:This is a message
# INFO, time: 2021-01-31 19:54:25,768 , line: 9- This is a message

# %%
import logging

LOGֹֹֹFORMAT = "%(levelname)s, time: %(asctime)s , line: %(lineno)d- %(message)s "
#create and configure logger
logging.basicConfig(filename= 'my_logging.log' ,
                    level= logging.DEBUG, 
                    format= LOGֹֹֹFORMAT,
                    filemode= 'w')
logger = logging.getLogger()

# Test the logger
logger.info('This is a message')


with open('my_logging.log') as file:
    print(file.read())
# Out:
#
#
# INFO, time: 2021-01-31 20:50:09,113 , line: 12- This is a message

# %%
def quadratic_formula(a:float, b:float ,c:float) -> float:
    import math
    """ Returns the solutions to the equation ax^2 + bx + c = 0  """
    logger.info(f'quadratic_formula({a},{b},{c})')
    logger.debug('Compute the discriminant')
    discri = b**2 - 4*a*c
    logger.debug('Compute the two roots')
    root_a = (-b + math.sqrt(discri))/(2*a)
    root_b = (-b - math.sqrt(discri))/(2*a)
    logger.debug('Return the two roots')
    return root_a , root_b

# %%
print(quadratic_formula(1,0,-4))
with open('my_logging.log') as file:
    print(file.read())
# Out:
# (2.0, -2.0)
#
#
# INFO, time: 2021-01-31 20:50:09,113 , line: 12- This is a message
# INFO, time: 2021-01-31 20:50:17,253 , line: 4- quadratic_formula(1,0,-4)
# DEBUG, time: 2021-01-31 20:50:17,254 , line: 5- Compute the discriminant
# DEBUG, time: 2021-01-31 20:50:17,254 , line: 7- Compute the two roots
# DEBUG, time: 2021-01-31 20:50:17,254 , line: 10- Return the two roots

# %%
print(quadratic_formula(1,0,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-537d663eba59> in <module>
# ----> 1 print(quadratic_formula(1,0,1))
#
# <ipython-input-10-9005406be729> in quadratic_formula(a, b, c)
#       6     discri = b**2 - 4*a*c
#       7     logger.debug('Compute the two roots')
# ----> 8     root_a = (-b + math.sqrt(discri))/(2*a)
#       9     root_b = (-b - math.sqrt(discri))/(2*a)
#      10     logger.debug('Return the two roots')
#
# ValueError: math domain error

# %%
with open('my_logging.log') as file:
    print(file.read())
# Out:
#
#
# INFO, time: 2021-01-31 20:50:09,113 , line: 12- This is a message
# INFO, time: 2021-01-31 20:50:17,253 , line: 4- quadratic_formula(1,0,-4)
# DEBUG, time: 2021-01-31 20:50:17,254 , line: 5- Compute the discriminant
# DEBUG, time: 2021-01-31 20:50:17,254 , line: 7- Compute the two roots
# DEBUG, time: 2021-01-31 20:50:17,254 , line: 10- Return the two roots
# INFO, time: 2021-01-31 20:50:35,846 , line: 4- quadratic_formula(1,0,1)
# DEBUG, time: 2021-01-31 20:50:35,846 , line: 5- Compute the discriminant
# DEBUG, time: 2021-01-31 20:50:35,846 , line: 7- Compute the two roots
